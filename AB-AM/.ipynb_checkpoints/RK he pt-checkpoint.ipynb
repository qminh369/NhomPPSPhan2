# %% [markdown]
# # Dung RK4

# %%
import numpy as np
import math
import scipy as sp
import matplotlib.pyplot as plt

#giai ptvp y" + xy' + y = 0
def f(x,y,z):
    return z - 2*y
def g(x,y,z):
    return -2*z + y
def RK4(x0, y0, z0, x, stepnum):
    h = (x-x0)/stepnum
    xk =[x0]
    yk =[y0]
    zk =[z0]
    print("xk", "".ljust(2),"|","yk", "".ljust(22), "|","zk".ljust(25))
    print("-----------------------------------------------------")
    print(x0,"".ljust(3),"|", y0,"".ljust(23),"|",z0,"".ljust(25))
    for i in range(stepnum):
        k1 = h*f(x0, y0 ,z0)
        l1 = h*g(x0, y0, z0)
        k2 = h*f(x0 + h/2, y0 + k1/2,z0 +l1/2)
        l2 = h*g(x0 + h/2, y0 + k1/2, z0 + l1/2)
        k3 = h*f(x0 + h/2, y0 + k2/2, z0 + l2/2)
        l3 = h*g(x0 + h/2, y0 + k2/2, z0 + l2/2)
        k4 = h*f(x0 + h, y0 + k3, z0 + l3)
        l4 = h*g(x0 + h, y0 + k3, z0 + l3 )
        y0 = y0 + 1/6*(k1 + 2*k2 + 2*k3 + k4)
        z0 = z0 + 1/6*(l1 + 2*l2 + 2*l3 + l4)
        x0 = x0 + h
        print(str(np.round(x0,3)).ljust(5) , "|", str(y0).ljust(25),"|",str(z0).ljust(7))
        xk.append(x0)
        yk.append(y0)
        zk.append(z0)
    return np.asarray(xk), np.asarray(yk), np.asarray(zk)

s1, s2, s3 = RK4(3.0, -0.5, 1.0, 6.0, 31)

plt.plot(s3, s2, 'go--', label = 'RK4')
plt.xlabel('z(k) or x(t)')
plt.ylabel('y(k) or y(t)')
#plt.plot(s1, kq, 'ro--', label = 'Nghiệm đúng')
plt.title('Biểu diễn nghiệm')
plt.legend()
plt.show()
# Out:
# xk    | yk                        | zk
# -----------------------------------------------------
# 3.0     | -0.5                         | 1.0
# 3.097 | -0.33408870778249766      | 0.7879692232228612
# 3.194 | -0.21366381121426548      | 0.6256788558070856
# 3.29  | -0.1269247646451921       | 0.5009359662631393
# 3.387 | -0.06507564059001461      | 0.4045884345316618
# 3.484 | -0.021565191553358447     | 0.329761675379024
# 3.581 | 0.008481346463452728      | 0.27128741140794876
# 3.677 | 0.028687044864354916      | 0.22527613118920906
# 3.774 | 0.04174082276343017       | 0.18879705173669664
# 3.871 | 0.04963477996557884       | 0.15963851864770798
# 3.968 | 0.053841550166329084      | 0.1361285951186784
# 4.065 | 0.05544680365764727       | 0.11700069126283262
# 4.161 | 0.05524821529037          | 0.10129290047144379
# 4.258 | 0.05382936091355874       | 0.08827256370560459
# 4.355 | 0.051614871837199885      | 0.0773797177452272
# 4.452 | 0.04891158091127915       | 0.06818468070610116
# 4.548 | 0.04593920008575697       | 0.0603562230723155
# 4.645 | 0.042853176457419304      | 0.05363766644645568
# 4.742 | 0.039761706004470536      | 0.04782892102050131
# 4.839 | 0.03673838474521791       | 0.04277297313845981
# 4.935 | 0.0338316035106102        | 0.038345708688603514
# 5.032 | 0.031071513158625913      | 0.034448238169532415
# 5.129 | 0.028475178144578346      | 0.031001098864119545
# 5.226 | 0.026050380139697654      | 0.027939866390665632
# 5.323 | 0.023798416579478857      | 0.025211825268428325
# 5.419 | 0.021716151688722443      | 0.022773435974847534
# 5.516 | 0.019797512240945715      | 0.02058840171999505
# 5.613 | 0.018034571507616635      | 0.018626187382627304
# 5.71  | 0.016418328379984012      | 0.01686087990309361
# 5.806 | 0.01493926139350928       | 0.015270307024431695
# 5.903 | 0.013587717026198922      | 0.013835351943333034
# 6.0   | 0.012354176437926408      | 0.0125394169197692

# %%
import numpy as np
import math
import scipy as sp
import matplotlib.pyplot as plt

#giai ptvp y" + xy' + y = 0
def f(x,y,z):
    return -0.35*y + (0.35*x**2*y) / (1 + 15*x**2)
def g(x,y,z):
    return 1.5*(1 - x/20) - (0.5*x**2*y) / (1 + 15*x**2)
def RK4(x0, y0, z0, x, stepnum):
    h = (x-x0)/stepnum
    xk =[x0]
    yk =[y0]
    zk =[z0]
    print("xk", "".ljust(2),"|","yk", "".ljust(22), "|","zk".ljust(25))
    print("-----------------------------------------------------")
    print(x0,"".ljust(3),"|", y0,"".ljust(23),"|",z0,"".ljust(25))
    for i in range(stepnum):
        k1 = h*f(x0, y0 ,z0)
        l1 = h*g(x0, y0, z0)
        k2 = h*f(x0 + h/2, y0 + k1/2,z0 +l1/2)
        l2 = h*g(x0 + h/2, y0 + k1/2, z0 + l1/2)
        k3 = h*f(x0 + h/2, y0 + k2/2, z0 + l2/2)
        l3 = h*g(x0 + h/2, y0 + k2/2, z0 + l2/2)
        k4 = h*f(x0 + h, y0 + k3, z0 + l3)
        l4 = h*g(x0 + h, y0 + k3, z0 + l3 )
        y0 = y0 + 1/6*(k1 + 2*k2 + 2*k3 + k4)
        z0 = z0 + 1/6*(l1 + 2*l2 + 2*l3 + l4)
        x0 = x0 + h
        print(str(np.round(x0,3)).ljust(5) , "|", str(y0).ljust(25),"|",str(z0).ljust(7))
        xk.append(x0)
        yk.append(y0)
        zk.append(z0)
    return np.asarray(xk), np.asarray(yk), np.asarray(zk)

s1, s2, s3 = RK4(0.0, 4.0, 6.0, 10.0, 101)

plt.plot(s3, s2, 'go--', label = 'RK4')
plt.xlabel('z(k) or x(t)')
plt.ylabel('y(k) or y(t)')
#plt.plot(s1, kq, 'ro--', label = 'Nghiệm đúng')
plt.title('Biểu diễn nghiệm')
plt.legend()
plt.show()
# Out:
# xk    | yk                        | zk
# -----------------------------------------------------
# 0.0     | 4.0                         | 6.0
# 0.099 | 3.864162096040264         | 6.147568065934548
# 0.198 | 3.7346953223530117        | 6.29186905976384
# 0.297 | 3.611460550348196         | 6.432784028014552
# 0.396 | 3.49362079063221          | 6.571220371438947
# 0.495 | 3.38045749068572          | 6.7079562687136995
# 0.594 | 3.271477120218362         | 6.843478273062941
# 0.693 | 3.166341201360699         | 6.978071717680448
# 6.238 | 0.5165704377092112        | 13.590415852587695
# 6.337 | 0.5001282323496672        | 13.690569355442399
# 6.436 | 0.48420943287485274       | 13.790040858659049
# 6.535 | 0.4687973732857933        | 13.888828674376608
# 6.634 | 0.45387591861978827       | 13.986931167944682
# 6.733 | 0.4394294479958033        | 14.084346756277418
# 6.832 | 0.4254428382046489        | 14.181073906254912
# 6.931 | 0.4119014478260499        | 14.277111133171173
# 7.03  | 0.3987911018553483        | 14.372456999227628
# 7.129 | 0.38609807682318587       | 14.467110112071166
# 7.228 | 0.3738090863920951        | 14.56106912337566
# 7.327 | 0.3619112674144799        | 14.654332727465912
# 7.426 | 0.35039216643700166       | 14.746899659982974
# 7.525 | 0.33923972663689506       | 14.83876869658977
# 7.624 | 0.32844227517622876       | 14.92993865171597
# 7.723 | 0.31798851096059727       | 15.020408377341063
# 7.822 | 0.30786749278918246       | 15.110176761814609
# 7.921 | 0.29806862788355976       | 15.199242728712612
# 8.02  | 0.28858166078304315       | 15.287605235729043
# 8.119 | 0.2793966625947677        | 15.375263273601487
# 8.218 | 0.27050402058709744       | 15.462215865069966
# 8.317 | 0.26189442811532226       | 15.548462063867966
# 8.416 | 0.2535588748689701        | 15.634000953744739
# 8.515 | 0.24548863743040933       | 15.718831647517963
# 8.614 | 0.23767527013475465       | 15.802953286155866
# 8.713 | 0.2301105962214146        | 15.886365037887941
# 8.812 | 0.2227866992679337        | 15.969066097343404
# 8.911 | 0.21569591489708573       | 16.05105568471655
# 9.01  | 0.20883082274846848       | 16.13233304495822
# 9.109 | 0.20218423870613317       | 16.21289744699256
# 9.208 | 0.19574920737405616       | 16.29274818295835
# 9.307 | 0.18951899479152529       | 16.371884567474098
# 9.406 | 0.18348708138076875       | 16.45030593692623
# 9.505 | 0.17764715511940257       | 16.528011648779625
# 9.604 | 0.17199310493051118       | 16.605001080909823
# 9.703 | 0.16651901428340754       | 16.681273630956277
# 9.802 | 0.1612191549983428        | 16.756828715695917
# 9.901 | 0.15608798124865156       | 16.831665770436498
# 10.0  | 0.15112012375402853       | 16.905784248429022

# %%
import numpy as np
import math
import scipy as sp
import matplotlib.pyplot as plt

#giai ptvp y" + xy' + y = 0
def f(x,y,z):
    return -0.35*y + (0.35*x**2*y) / (1 + 15*x**2)
def g(x,y,z):
    return 1.5*(1 - x/20) - (0.5*x**2*y) / (1 + 15*x**2)
def RK4(x0, y0, z0, x, stepnum):
    h = (x-x0)/stepnum
    xk =[x0]
    yk =[y0]
    zk =[z0]
    print("xk", "".ljust(2),"|","yk", "".ljust(22), "|","zk".ljust(25))
    print("-----------------------------------------------------")
    print(x0,"".ljust(3),"|", y0,"".ljust(23),"|",z0,"".ljust(25))
    for i in range(stepnum):
        y_temp = y0 + h * f(x0, y0, z0)
        y0 = y0 + (h/2) * (f(x0, y0, z0) + f(x0+h, y_temp, z0))
        
        z_temp = z0 + h * g(x0, y0, z0)
        z0 = z0 + (h/2) * (g(x0, y0, z0) + g(x0+h, y0, z_temp))
        
        x0 = x0 + h
        print(str(np.round(x0,3)).ljust(5) , "|", str(y0).ljust(25),"|",str(z0).ljust(7))
        xk.append(x0)
        yk.append(y0)
        zk.append(z0)
    return np.asarray(xk), np.asarray(yk), np.asarray(zk)

s1, s2, s3 = RK4(0.0, 4.0, 6.0, 10.0, 101)

plt.plot(s3, s2, 'go--', label = 'RK2 (hinh thang)')
plt.xlabel('z(k) or x(t)')
plt.ylabel('y(k) or y(t)')
#plt.plot(s1, kq, 'ro--', label = 'Nghiệm đúng')
plt.title('Biểu diễn nghiệm')
plt.legend()
plt.show()
# Out:
# xk    | yk                        | zk
# -----------------------------------------------------
# 0.0     | 4.0                         | 6.0
# 0.099 | 3.8643596544260803        | 6.147329767885699
# 0.198 | 3.7349152373550987        | 6.291669161034294
# 0.297 | 3.61164677913044          | 6.432744068414691
# 0.396 | 3.4937831278678946        | 6.571356019654783
# 0.495 | 3.3806109481221958        | 6.708262130243235
# 0.594 | 3.2716310771144816        | 6.843948145918642
# 0.693 | 3.166500589350943         | 6.9787006287480855
# 0.792 | 3.0649707033360154        | 7.112688116158433
# 0.891 | 2.9668483843053024        | 7.246011467287294
# 0.99  | 2.871974714900576         | 7.378732102375507
# 1.089 | 2.7802127201963645        | 7.510887768958291
# 1.188 | 2.6914403273200787        | 7.642501552513684
# 1.287 | 2.6055461476238704        | 7.7735871896385715
# 1.386 | 2.5224268539650616        | 7.90415230301445
# 1.485 | 2.44198548865359          | 8.03420043159833
# 1.584 | 2.364130332039007         | 8.163732340457232
# 1.683 | 2.2887741192939917        | 8.292746887109626
# 1.782 | 2.215833479726794         | 8.421241607353792
# 1.881 | 2.1452285221573764        | 8.54921311923806
# 1.98  | 2.076882518592595         | 8.67665740645746
# 2.079 | 2.0107216556311283        | 8.80357002016531
# 2.178 | 1.9466748335910786        | 8.929946224552351
# 2.277 | 1.8846734999923203        | 9.05578110301314
# 2.376 | 1.8246515082887853        | 9.18106963626545
# 2.475 | 1.7665449955377137        | 9.305806760233766
# 2.574 | 1.7102922745547906        | 9.429987409149016
# 2.673 | 1.6558337373669434        | 9.55360654772488
# 2.772 | 1.603111767644626         | 9.67665919518033
# 2.871 | 1.552070660403686         | 9.799140443119748
# 2.97  | 1.5026565476979874        | 9.921045468747982
# 3.069 | 1.4548173293334206        | 10.042369544516687
# 3.168 | 1.4085026078587737        | 10.16310804502361
# 3.267 | 1.3636636272541802        | 10.283256451786002
# 3.366 | 1.3202532148606263        | 10.402810356361764
# 3.465 | 1.2782257261861694        | 10.521765462182207
# 3.564 | 1.2375369922943984        | 10.640117585377913
# 3.663 | 1.198144269534173         | 10.757862654816929
# 3.762 | 1.160006191411026         | 10.874996711527064
# 3.861 | 1.1230827224328597        | 10.991515907637579
# 3.96  | 1.0873351137879483        | 11.10741650494736
# 4.059 | 1.0527258607334082        | 11.222694873204757
# 4.158 | 1.019218661588435         | 11.337347488167062
# 9.703 | 0.16661417025360056       | 16.686682125975558
# 9.802 | 0.16131221446600436       | 16.762245596199435
# 9.901 | 0.1561789812808455        | 16.837090766665725
# 10.0  | 0.15120910118190592       | 16.911217099299645

# %% [markdown]
# # Hinh thang = RK2

# %%
import numpy as np
import math
import scipy as sp
import matplotlib.pyplot as plt

#giai ptvp y" + xy' + y = 0
def f(x,y,z):
    return z - 2*y
def g(x,y,z):
    return -2*z + y
def HinhThang(x0, y0, z0, x, stepnum):
    h = (x-x0)/stepnum
    xk =[x0]
    yk =[y0]
    zk =[z0]
    print("xk", "".ljust(2),"|","yk", "".ljust(22), "|","zk".ljust(25))
    print("-----------------------------------------------------")
    print(x0,"".ljust(3),"|", y0,"".ljust(23),"|",z0,"".ljust(25))
    for i in range(stepnum):
        y_temp = y0 + h * f(x0, y0, z0)
        y0 = y0 + (h/2) * (f(x0, y0, z0) + f(x0+h, y_temp, z0))
        
        z_temp = z0 + h * g(x0, y0, z0)
        z0 = z0 + (h/2) * (g(x0, y0, z0) + g(x0+h, y0, z_temp))
        
        x0 = x0 + h
        print(str(np.round(x0,3)).ljust(5) , "|", str(y0).ljust(25),"|",str(z0).ljust(7))
        xk.append(x0)
        yk.append(y0)
        zk.append(z0)
    return np.asarray(xk), np.asarray(yk), np.asarray(zk)

s1, s2, s3 = HinhThang(3.0, -0.5, 1.0, 6.0, 31)

plt.plot(s3, s2, 'go--', label = 'hinh thang')
plt.xlabel('z(k) or x(t)')
plt.ylabel('y(k) or y(t)')
#plt.plot(s1, kq, 'ro--', label = 'Nghiệm đúng')
plt.title('Biểu diễn nghiệm')
plt.legend()
plt.show()
# Out:
# xk    | yk                        | zk
# -----------------------------------------------------
# 3.0     | -0.5                         | 1.0
# 3.097 | -0.3251821019771072       | 0.7967582762059553
# 3.194 | -0.19869064689546903      | 0.6401033285037494
# 3.29  | -0.10800520644515296      | 0.5187611885141316
# 3.387 | -0.04377959300293367      | 0.42424571974969816
# 3.484 | 0.0009567359080626878     | 0.3501636020580519
# 3.581 | 0.03139691378560881       | 0.2916931084183416
# 3.677 | 0.05140475935393182       | 0.24519316832619686
# 3.774 | 0.06385036452348436       | 0.2079101072868333
# 3.871 | 0.0708613819762925        | 0.17775761827728134
# 3.968 | 0.07401115072059479       | 0.1531516419921062
# 4.065 | 0.0744595009872722        | 0.13288642058550582
# 4.161 | 0.07305810989811587       | 0.11604142846591867
# 4.258 | 0.07042930399619464       | 0.10191146129984792
# 4.355 | 0.06702497483680497       | 0.08995409645897089
# 4.452 | 0.06317060265155036       | 0.07975018638365676
# 4.548 | 0.05909813065442935       | 0.07097413192217678
# 4.645 | 0.054970493954656946      | 0.06337149646875896
# 4.742 | 0.05089990365184049       | 0.0567421317445166
# 4.839 | 0.046961459586315195      | 0.05092744337008548
# 4.935 | 0.043203270234167666      | 0.04580076721347333
# 5.032 | 0.03965396227016308       | 0.0412600845275526
# 5.129 | 0.036328240562490885      | 0.0372224966052013
# 5.226 | 0.03323099321632901       | 0.03362002418116157
# 5.323 | 0.03036031181245211       | 0.030396405169518317
# 5.419 | 0.02770970374767332       | 0.027504645592333597
# 5.516 | 0.025269703747826187      | 0.02490513951044531
# 5.613 | 0.02302903932456147       | 0.02256421949536555
# 5.71  | 0.020975465787708585      | 0.020453033492187724
# 5.806 | 0.01909635711029831       | 0.018546669673850075
# 5.903 | 0.017379117004235136      | 0.016823470218229823
# 6.0   | 0.015811458150561675      | 0.015264489456507211

# %%
import numpy as np
import math
import scipy as sp
import matplotlib.pyplot as plt

#giai ptvp y" + xy' + y = 0
def f(x,y,z):
    return z
def g(x,y,z):
    return x * y**2 * (1 + math.sin(x*y)) + x**3 + z
def RK4(x0, y0, z0, x, stepnum):
    h = (x-x0)/stepnum
    xk =[x0]
    yk =[y0]
    zk =[z0]
    print("xk", "".ljust(2),"|","yk", "".ljust(22), "|","zk".ljust(25))
    print("-----------------------------------------------------")
    print(x0,"".ljust(3),"|", y0,"".ljust(23),"|",z0,"".ljust(25))
    for i in range(stepnum):
        k1 = h*f(x0, y0 ,z0)
        l1 = h*g(x0, y0, z0)
        k2 = h*f(x0 + h/2, y0 + k1/2,z0 +l1/2)
        l2 = h*g(x0 + h/2, y0 + k1/2, z0 + l1/2)
        k3 = h*f(x0 + h/2, y0 + k2/2, z0 + l2/2)
        l3 = h*g(x0 + h/2, y0 + k2/2, z0 + l2/2)
        k4 = h*f(x0 + h, y0 + k3, z0 + l3)
        l4 = h*g(x0 + h, y0 + k3, z0 + l3 )
        y0 = y0 + 1/6*(k1 + 2*k2 + 2*k3 + k4)
        z0 = z0 + 1/6*(l1 + 2*l2 + 2*l3 + l4)
        x0 = x0 + h
        print(str(np.round(x0,3)).ljust(5) , "|", str(y0).ljust(25),"|",str(z0).ljust(7))
        xk.append(x0)
        yk.append(y0)
        zk.append(z0)
    return np.asarray(xk), np.asarray(yk), np.asarray(zk)

s1, s2, s3 = RK4(0.0, 1.0, 1.0, 1.0, 10)

plt.plot(s3, s2, 'go--', label = 'RK4')
plt.xlabel('z(k) or x(t)')
plt.ylabel('y(k) or y(t)')
#plt.plot(s1, kq, 'ro--', label = 'Nghiệm đúng')
plt.title('Biểu diễn nghiệm')
plt.legend()
plt.show()
# Out:
# xk    | yk                        | zk
# -----------------------------------------------------
# 0.0     | 1.0                         | 1.0
# 0.1   | 1.1053699602014018        | 1.1115340373702782
# 0.2   | 1.2233348926585559        | 1.2541936776455436
# 0.3   | 1.3578247032064952        | 1.4457893251996863
# 0.4   | 1.5150634700888568        | 1.7152593686784188
# 0.5   | 1.704987003995968         | 2.1092926447421063
# 0.6   | 1.943492389630883         | 2.702379798011704
# 0.7   | 2.2557853864324806        | 3.6072128136268096
# 0.8   | 2.679909653765602         | 4.95858374876174
# 0.9   | 3.263166893210029         | 6.756602253984165
# 1.0   | 4.028171602273114         | 8.445454438408541
