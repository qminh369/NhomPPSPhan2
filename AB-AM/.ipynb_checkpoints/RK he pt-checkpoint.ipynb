# %% [markdown]
# # Dung RK4

# %%
import numpy as np
import math
import scipy as sp
import matplotlib.pyplot as plt

#giai ptvp y" + xy' + y = 0
def f(x,y,z):
    return z - 2*y
def g(x,y,z):
    return -2*z + y
def RK4(x0, y0, z0, x, stepnum):
    h = (x-x0)/stepnum
    xk =[x0]
    yk =[y0]
    zk =[z0]
    print("t", "".ljust(2),"|","y", "".ljust(22), "|","x".ljust(25))
    print("-----------------------------------------------------")
    print(x0,"".ljust(3),"|", y0,"".ljust(23),"|",z0,"".ljust(25))
    for i in range(stepnum):
        k1 = h*f(x0, y0 ,z0)
        l1 = h*g(x0, y0, z0)
        k2 = h*f(x0 + h/2, y0 + k1/2,z0 +l1/2)
        l2 = h*g(x0 + h/2, y0 + k1/2, z0 + l1/2)
        k3 = h*f(x0 + h/2, y0 + k2/2, z0 + l2/2)
        l3 = h*g(x0 + h/2, y0 + k2/2, z0 + l2/2)
        k4 = h*f(x0 + h, y0 + k3, z0 + l3)
        l4 = h*g(x0 + h, y0 + k3, z0 + l3 )
        y0 = y0 + 1/6*(k1 + 2*k2 + 2*k3 + k4)
        z0 = z0 + 1/6*(l1 + 2*l2 + 2*l3 + l4)
        x0 = x0 + h
        print(str(np.round(x0,3)).ljust(5) , "|", str(y0).ljust(25),"|",str(z0).ljust(7))
        xk.append(x0)
        yk.append(y0)
        zk.append(z0)
    return np.asarray(xk), np.asarray(yk), np.asarray(zk)

s1, s2, s3 = RK4(3.0, -0.5, 1.0, 6.0, 30)

fig = plt.figure(figsize = (16, 8))
plt.subplot(1, 2, 1)
plt.plot(s1, s3, 'go--', c = 'r', label = 'x(t)')
plt.plot(s1, s2, 'go--', c = 'b', label = 'y(t)')
plt.xlabel("Value of t")
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(s3, s2, 'go--', c = 'g', label = 'RK4')
plt.xlabel("Value of x")
plt.ylabel("Value of y")
plt.legend()
plt.show()
# Out:
# t    | y                        | x
# -----------------------------------------------------
# 3.0     | -0.5                         | 1.0
# 3.1   | -0.32941875               | 0.7818375
# 3.2   | -0.206947425703125        | 0.61631287640625
# 3.3   | -0.11974644653168261      | 0.49015565753227147
# 3.4   | -0.05833910278036712      | 0.39349924723911245
# 3.5   | -0.015736663210433113     | 0.3190021304221231
# 3.6   | 0.013209458080199334      | 0.2611965091079582
# 3.7   | 0.03228735120991859       | 0.21600545812569594
# 3.8   | 0.04427969091749845       | 0.18038495394971565
# 3.9   | 0.051226556399203815      | 0.15205843920083403
# 4.0   | 0.05461992361559826       | 0.12931996359065098
# 4.1   | 0.05554755841248321       | 0.11088814927750133
# 4.2   | 0.05479944233598676       | 0.09579782732094963
# 4.3   | 0.052946457973455374      | 0.0833195990097528
# 4.4   | 0.05039853823153281       | 0.07290010010401081
# 4.5   | 0.04744761541061777       | 0.06411761625431969
# 4.6   | 0.04429932177828841       | 0.056649083528334435
# 4.7   | 0.04109636803306581       | 0.050245534653565536
# 4.8   | 0.03793576657300016       | 0.04471381229921463
# 4.9   | 0.034881503936046616      | 0.03990293438674103
# 5.0   | 0.03197385011468952       | 0.03569391409620584
# 5.1   | 0.029236183849634716      | 0.03199214674954132
# 5.2   | 0.026679984461836195      | 0.02872170512669575
# 5.3   | 0.02430847153500519       | 0.025821054768058082
# 5.4   | 0.022119248437665596      | 0.02323982681858242
# 5.5   | 0.020106212885451422      | 0.02093637937172389
# 5.6   | 0.018260929053613994      | 0.018875947517887872
# 5.7   | 0.01657360490661991       | 0.01702923364814641
# 5.8   | 0.015033780786498866      | 0.015371327644299503
# 5.9   | 0.01363080746474332       | 0.013880874835009199
# 6.0   | 0.012354171273741485      | 0.012539430559160833
# C:\Users\admin\AppData\Local\Temp/ipykernel_16672/1706275198.py:41: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "go--" (-> color='g'). The keyword argument will take precedence.
#   plt.plot(s1, s3, 'go--', c = 'r', label = 'x(t)')
# C:\Users\admin\AppData\Local\Temp/ipykernel_16672/1706275198.py:42: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "go--" (-> color='g'). The keyword argument will take precedence.
#   plt.plot(s1, s2, 'go--', c = 'b', label = 'y(t)')
# C:\Users\admin\AppData\Local\Temp/ipykernel_16672/1706275198.py:47: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "go--" (-> color='g'). The keyword argument will take precedence.
#   plt.plot(s3, s2, 'go--', c = 'g', label = 'RK4')

# %%
import numpy as np
import math
import scipy as sp
import matplotlib.pyplot as plt

#giai ptvp y" + xy' + y = 0
def f(x,y,z):
    return -0.35*y + (0.35*x**2*y) / (1 + 15*x**2)
def g(x,y,z):
    return 1.5*(1 - x/20) - (0.5*x**2*y) / (1 + 15*x**2)
def RK4(x0, y0, z0, x, stepnum):
    h = (x-x0)/stepnum
    xk =[x0]
    yk =[y0]
    zk =[z0]
    print("t", "".ljust(2),"|","y", "".ljust(22), "|","x".ljust(25))
    print("-----------------------------------------------------")
    print(x0,"".ljust(3),"|", y0,"".ljust(23),"|",z0,"".ljust(25))
    for i in range(stepnum):
        k1 = h*f(x0, y0 ,z0)
        l1 = h*g(x0, y0, z0)
        k2 = h*f(x0 + h/2, y0 + k1/2,z0 +l1/2)
        l2 = h*g(x0 + h/2, y0 + k1/2, z0 + l1/2)
        k3 = h*f(x0 + h/2, y0 + k2/2, z0 + l2/2)
        l3 = h*g(x0 + h/2, y0 + k2/2, z0 + l2/2)
        k4 = h*f(x0 + h, y0 + k3, z0 + l3)
        l4 = h*g(x0 + h, y0 + k3, z0 + l3 )
        y0 = y0 + 1/6*(k1 + 2*k2 + 2*k3 + k4)
        z0 = z0 + 1/6*(l1 + 2*l2 + 2*l3 + l4)
        x0 = x0 + h
        print(str(np.round(x0,3)).ljust(5) , "|", str(y0).ljust(25),"|",str(z0).ljust(7))
        xk.append(x0)
        yk.append(y0)
        zk.append(z0)
    return np.asarray(xk), np.asarray(yk), np.asarray(zk)

s1, s2, s3 = RK4(0.0, 4.0, 6.0, 10.0, 100)

fig = plt.figure(figsize = (16, 8))
plt.subplot(1, 2, 1)
plt.plot(s1, s3, 'go--', c = 'r', label = 'x(t)')
plt.plot(s1, s2, 'go--', c = 'b', label = 'y(t)')
plt.xlabel("Value of t")
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(s3, s2, 'go--', c = 'g', label = 'RK4')
plt.xlabel("Value of x")
plt.ylabel("Value of y")
plt.legend()
plt.show()
# Out:
# t    | y                        | x
# -----------------------------------------------------
# 0.0     | 4.0                         | 6.0
# 0.1   | 3.862834771732503         | 6.149029373316799
# 0.2   | 3.732172084696626         | 6.294717948816722
# 0.3   | 3.607851052004625         | 6.436968517344567
# 0.4   | 3.489008418985027         | 6.576718344586739
# 0.5   | 3.3749124442646132        | 6.714758171190927
# 0.6   | 3.265063355640604         | 6.851577945559735
# 0.7   | 3.1591189092396017        | 6.987463300753219
# 0.8   | 3.056829928713045         | 7.122581493051261
# 0.9   | 2.9580020921421175        | 7.257032385553498
# 1.0   | 2.8624746799678293        | 7.390876648932547
# 1.1   | 2.7701086553416716        | 7.524151435414525
# 1.2   | 2.680779772579766         | 7.656879327204244
# 1.3   | 2.594374443350807         | 7.789073614188801
# 1.4   | 2.510787161264648         | 7.920741509487518
# 1.5   | 2.4299188364822815        | 8.051886169015084
# 1.6   | 2.35167567918782          | 8.182507995384233
# 1.7   | 2.275968424397021         | 8.312605500823482
# 1.8   | 2.202711775212382         | 8.442175890933157
# 1.9   | 2.1318239896657003        | 8.571215467320759
# 2.0   | 2.0632265643352574        | 8.699719910071183
# 2.1   | 1.9968439847461361        | 8.827684478862045
# 2.2   | 1.9326035229052432        | 8.955104157979054
# 2.3   | 1.8704350688303388        | 9.081973761997151
# 2.4   | 1.8102709871148326        | 9.208288013463092
# 2.5   | 1.7520459923113691        | 9.334041600373748
# 2.6   | 1.6956970387467956        | 9.459229218892824
# 2.7   | 1.6411632216228824        | 9.58384560516107
# 2.8   | 1.5883856871132844        | 9.707885558966632
# 2.9   | 1.5373075497661022        | 9.831343961285297
# 3.0   | 1.487873815946094         | 9.954215787166955
# 3.1   | 1.4400313123556279        | 10.076496115064167
# 3.2   | 1.3937286188952247        | 10.198180133424056
# 3.3   | 1.3489160052876228        | 10.31926314516452
# 3.4   | 1.3055453710105254        | 10.439740570508125
# 3.5   | 1.2635701881742671        | 10.559607948537375
# 3.6   | 1.2229454470497416        | 10.678860937752626
# 3.7   | 1.1836276040048783        | 10.797495315851707
# 3.8   | 1.1455745316489143        | 10.915506978902757
# 3.9   | 1.1087454710156786        | 11.032891940045351
# 4.0   | 1.073100985642295         | 11.149646327826785
# 4.1   | 1.038602917419738         | 11.265766384258434
# 4.2   | 1.0052143441077297        | 11.381248462659917
# 4.3   | 0.9728995384194766        | 11.49608902534528
# 4.4   | 0.9416239285923472        | 11.610284641194687
# 4.5   | 0.9113540603693447        | 11.72383198314659
# 4.6   | 0.8820575603234919        | 11.836727825638539
# 4.7   | 0.8537031004633421        | 11.948969042019309
# 4.8   | 0.8262603640629853        | 12.06055260195065
# 4.9   | 0.799700012664321         | 12.171475568813342
# 5.0   | 0.7739936542031532        | 12.281735097129385
# 5.1   | 0.749113812213956         | 12.391328430009784
# 5.2   | 0.7250338960710313        | 12.500252896635457
# 5.3   | 0.7017281722263231        | 12.608505909777202
# 5.4   | 0.6791717364064067        | 12.716084963359403
# 5.5   | 0.6573404867331932        | 12.82298763007105
# 5.6   | 0.6362110977347128        | 12.929211559026797
# 5.7   | 0.615760995213992         | 13.034754473480048
# 5.8   | 0.59596833194555          | 13.139614168589477
# 5.9   | 0.5768119641704272        | 13.24378850923987
# 6.0   | 0.5582714288619338        | 13.347275427917822
# 6.1   | 0.5403269217354957        | 13.450072922642422
# 6.2   | 0.5229592759770774        | 13.552179054950848
# 6.3   | 0.5061499416656938        | 13.653591947938535
# 6.4   | 0.489880965866492         | 13.754309784353396
# 6.5   | 0.4741349733717932        | 13.854330804743435
# 6.6   | 0.4588951480683497        | 13.953653305656987
# 6.7   | 0.44414521490988024       | 14.052275637894672
# 6.8   | 0.42986942247472415       | 14.150196204812147
# 6.9   | 0.4160525260891858        | 14.247413460672615
# 7.0   | 0.4026797714978409        | 14.343925909048044
# 7.1   | 0.38973687906274285       | 14.439732101268005
# 7.2   | 0.3772100284741039        | 14.534830634915005
# 7.3   | 0.36508584395563604       | 14.629220152365209
# 7.4   | 0.3533513799483182        | 14.722899339373383
# 7.5   | 0.34199410725691803       | 14.815866923700954
# 7.6   | 0.33100189964413074       | 14.90812167378603
# 7.7   | 0.3203630208577153        | 14.999662397454257
# 7.8   | 0.3100661120765018        | 15.090487940669421
# 7.9   | 0.30010017976162134       | 15.180597186322645
# 8.0   | 0.29045458389976797       | 15.269989053059147
# 8.1   | 0.2811190266257436        | 15.358662494141461
# 8.2   | 0.2720835412119623        | 15.446616496348073
# 8.3   | 0.26333848141299987       | 15.533850078906458
# 8.4   | 0.25487451115367          | 15.620362292459495
# 8.5   | 0.2466825945494895        | 15.706152218064288
# 8.6   | 0.23875398624876218       | 15.791218966222415
# 8.7   | 0.23108022208586618       | 15.875561675940682
# 8.8   | 0.2236531100356719        | 15.959179513821452
# 8.9   | 0.21646472145934814       | 16.042071673181663
# 9.0   | 0.20950738263213345       | 16.12423737319965
# 9.1   | 0.20277366654395798       | 16.20567585808896
# 9.2   | 0.19625638496409897       | 16.286386396298266
# 9.3   | 0.18994858076134094       | 16.366368279736662
# 9.4   | 0.18384352047138955       | 16.44562082302349
# 9.5   | 0.17793468710355698       | 16.52414336276196
# 9.6   | 0.17221577317899658       | 16.601935256835866
# 9.7   | 0.16668067399301523       | 16.678995883728597
# 9.8   | 0.161323481094235         | 16.75532464186384
# 9.9   | 0.15613847597361036       | 16.830920948967233
# 10.0  | 0.15112012395653363       | 16.905784241448337
# C:\Users\admin\AppData\Local\Temp/ipykernel_16672/2100444609.py:41: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "go--" (-> color='g'). The keyword argument will take precedence.
#   plt.plot(s1, s3, 'go--', c = 'r', label = 'x(t)')
# C:\Users\admin\AppData\Local\Temp/ipykernel_16672/2100444609.py:42: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "go--" (-> color='g'). The keyword argument will take precedence.
#   plt.plot(s1, s2, 'go--', c = 'b', label = 'y(t)')
# C:\Users\admin\AppData\Local\Temp/ipykernel_16672/2100444609.py:47: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "go--" (-> color='g'). The keyword argument will take precedence.
#   plt.plot(s3, s2, 'go--', c = 'g', label = 'RK4')

# %% [markdown]
# # Hinh thang = RK2

# %%
import numpy as np
import math
import scipy as sp
import matplotlib.pyplot as plt

#giai ptvp y" + xy' + y = 0
def f(x,y,z):
    return -0.35*y + (0.35*x**2*y) / (1 + 15*x**2)
def g(x,y,z):
    return 1.5*(1 - x/20) - (0.5*x**2*y) / (1 + 15*x**2)
def RK4(x0, y0, z0, x, stepnum):
    h = (x-x0)/stepnum
    xk =[x0]
    yk =[y0]
    zk =[z0]
    print("t", "".ljust(2),"|","y", "".ljust(22), "|","x".ljust(25))
    print("-----------------------------------------------------")
    print(x0,"".ljust(3),"|", y0,"".ljust(23),"|",z0,"".ljust(25))
    for i in range(stepnum):
        y_temp = y0 + h * f(x0, y0, z0)
        y0 = y0 + (h/2) * (f(x0, y0, z0) + f(x0+h, y_temp, z0))
        
        z_temp = z0 + h * g(x0, y0, z0)
        z0 = z0 + (h/2) * (g(x0, y0, z0) + g(x0+h, y0, z_temp))
        
        x0 = x0 + h
        print(str(np.round(x0,3)).ljust(5) , "|", str(y0).ljust(25),"|",str(z0).ljust(7))
        xk.append(x0)
        yk.append(y0)
        zk.append(z0)
    return np.asarray(xk), np.asarray(yk), np.asarray(zk)

s1, s2, s3 = RK4(0.0, 4.0, 6.0, 10.0, 100)

fig = plt.figure(figsize = (16, 8))
plt.subplot(1, 2, 1)
plt.plot(s1, s3, 'go--', c = 'r', label = 'x(t)')
plt.plot(s1, s2, 'go--', c = 'b', label = 'y(t)')
plt.xlabel("Value of t")
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(s3, s2, 'go--', c = 'g', label = 'RK2')
plt.xlabel("Value of x")
plt.ylabel("Value of y")
plt.legend()
plt.show()
# Out:
# t    | y                        | x
# -----------------------------------------------------
# 0.0     | 4.0                         | 6.0
# 0.1   | 3.863037391304348         | 6.14878520926276
# 0.2   | 3.732395912124343         | 6.294516071402003
# 0.3   | 3.608040054316618         | 6.436931539933071
# 0.4   | 3.4891734095432807        | 6.576860932094183
# 0.5   | 3.3750688511476223        | 6.715074382790239
# 0.6   | 3.2652206573334235        | 6.852061323270688
# 0.7   | 3.159282031579614         | 6.988108708077031
# 0.8   | 3.057001210277946         | 7.123384544492716
# 0.9   | 2.958182482043334         | 7.257988987322241
# 1.0   | 2.8626643830605114        | 7.391982788766905
# 1.1   | 2.770307474865409         | 7.52540311017217
# 1.2   | 2.680987295192847         | 7.658272531009841
# 1.3   | 2.5945901416255057        | 7.79060434935869
# 1.4   | 2.5110104519442236        | 7.922405803756092
# 1.5   | 2.4301491143421536        | 8.053680092481981
# 1.6   | 2.3519123370473793        | 8.1844276749203
# 1.7   | 2.276210865050331         | 8.314647131465001
# 1.8   | 2.202959418524199         | 8.444335744477621
# 1.9   | 2.132076276710473         | 8.573489898549882
# 2.0   | 2.0634829596931334        | 8.702105361048119
# 2.1   | 1.9971039776326076        | 8.830177481701568
# 2.2   | 1.932866627554281         | 8.95770133642301
# 2.3   | 1.8707008243966436        | 9.084671832062938
# 2.4   | 1.8105389572661903        | 9.21108378337726
# 2.5   | 1.7523157646228913        | 9.336931969957247
# 2.6   | 1.6959682239711027        | 9.462211178528124
# 2.7   | 1.6414354528858515        | 9.586916234442887
# 2.8   | 1.5886586190689083        | 9.711042025115766
# 2.9   | 1.5375808577332917        | 9.834583517387774
# 3.0   | 1.4881471950430074        | 9.957535770287242
# 3.1   | 1.4403044766421658        | 10.079893944270731
# 3.2   | 1.3940013005309109        | 10.201653307757368
# 3.3   | 1.3491879537097085        | 10.322809241571171
# 3.4   | 1.3058163521354862        | 10.443357241759717
# 3.5   | 1.263839983624676         | 10.563292921148829
# 3.6   | 1.223213853407665         | 10.682612009911441
# 3.7   | 1.1838944320923426        | 10.80131035536718
# 3.8   | 1.1458396058355655        | 10.919383921182174
# 3.9   | 1.1090086285534542        | 11.036828786102596
# 4.0   | 1.0733620760267117        | 11.153641142327501
# 4.1   | 1.0388618017772484        | 11.269817293604852
# 4.2   | 1.0054708946085003        | 11.385353653117662
# 4.3   | 0.9731536377148671        | 11.50024674121377
# 4.4   | 0.9418754692763301        | 11.61449318302221
# 4.5   | 0.9116029444630777        | 11.728089705990717
# 4.6   | 0.8823036987822435        | 11.841033137372168
# 4.7   | 0.8539464127049722        | 11.953320401682362
# 4.8   | 0.8265007775171861        | 12.064948518147204
# 4.9   | 0.7999374623418349        | 12.17591459815381
# 5.0   | 0.7742280822842029        | 12.286215842717194
# 5.1   | 0.7493451676551353        | 12.395849539971907
# 5.2   | 0.7252621342299296        | 12.504813062696039
# 5.3   | 0.7019532545031747        | 12.613103865873466
# 5.4   | 0.6793936299020793        | 12.720719484298973
# 5.5   | 0.6575591639228526        | 12.827657530229766
# 5.6   | 0.6364265361565223        | 12.933915691086089
# 5.7   | 0.6159731771722279        | 13.039491727202904
# 5.8   | 0.5961772442275373        | 13.144383469634043
# 5.9   | 0.5770175977767201        | 13.248588818009699
# 6.0   | 0.5584737787491885        | 13.352105738447797
# 6.1   | 0.5405259865715015        | 13.454932261519387
# 6.2   | 0.5231550579074358        | 13.557066480267983
# 6.3   | 0.5063424460916505        | 13.658506548282523
# 6.4   | 0.49007020123345013       | 13.759250677823438
# 6.5   | 0.4743209509680523        | 13.85929713800121
# 6.6   | 0.4590778818336319        | 13.958644253006625
# 6.7   | 0.4443247212532251        | 14.057290400391874
# 6.8   | 0.4300457201013479        | 14.155234009401575
# 6.9   | 0.41622563583591776       | 14.252473559352696
# 7.0   | 0.40284971617676535       | 14.34900757806237
# 7.1   | 0.38990368331268915       | 14.444834640322512
# 7.2   | 0.3773737186196427        | 14.539953366420145
# 7.3   | 0.3652464478732519        | 14.634362420702343
# 7.4   | 0.3535089269394443        | 14.728060510184656
# 7.5   | 0.3421486279275293        | 14.821046383201908
# 7.6   | 0.3311534257906058        | 14.913318828100257
# 7.7   | 0.3205115853586883        | 15.004876671969411
# 7.8   | 0.31021174879043706       | 15.095718779413895
# 7.9   | 0.30024292342985515       | 15.185844051362299
# 8.0   | 0.2905944700547713        | 15.275251423913424
# 8.1   | 0.28125609150437064       | 15.3639398672183
# 8.2   | 0.27221782167345904       | 15.451908384397006
# 8.3   | 0.2634700148615563        | 15.53915601048934
# 8.4   | 0.25500333546530846       | 15.625681811438282
# 8.5   | 0.24680874800309063       | 15.711484883105333
# 8.6   | 0.2388775074610377        | 15.796564350316764
# 8.7   | 0.23120114995009622       | 15.88091936593984
# 8.8   | 0.223771483664032         | 15.964549109988145
# 8.9   | 0.21658058012865838       | 16.047452788755102
# 9.0   | 0.20962076573286928       | 16.12962963397485
# 9.1   | 0.20288461353236908       | 16.21107890200964
# 9.2   | 0.196364935317289         | 16.291799873062917
# 9.3   | 0.19005477393516726       | 16.371791850417356
# 9.4   | 0.18394739586104808       | 16.451054159697005
# 9.5   | 0.17803628400672297       | 16.529586148152852
# 9.6   | 0.17231513076139773       | 16.607387183971078
# 9.7   | 0.16677783125631881       | 16.684456655603256
# 9.8   | 0.16141847684613583       | 16.760793971117863
# 9.9   | 0.15623134880001124       | 16.83639855757241
# 10.0  | 0.1512109121957147        | 16.911269860405543
# C:\Users\admin\AppData\Local\Temp/ipykernel_16672/2809627977.py:37: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "go--" (-> color='g'). The keyword argument will take precedence.
#   plt.plot(s1, s3, 'go--', c = 'r', label = 'x(t)')
# C:\Users\admin\AppData\Local\Temp/ipykernel_16672/2809627977.py:38: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "go--" (-> color='g'). The keyword argument will take precedence.
#   plt.plot(s1, s2, 'go--', c = 'b', label = 'y(t)')
# C:\Users\admin\AppData\Local\Temp/ipykernel_16672/2809627977.py:43: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "go--" (-> color='g'). The keyword argument will take precedence.
#   plt.plot(s3, s2, 'go--', c = 'g', label = 'RK2')

# %%
import numpy as np
import math
import scipy as sp
import matplotlib.pyplot as plt

#giai ptvp y" + xy' + y = 0
def f(x,y,z):
    return z - 2*y
def g(x,y,z):
    return -2*z + y
def HinhThang(x0, y0, z0, x, stepnum):
    h = (x-x0)/stepnum
    xk =[x0]
    yk =[y0]
    zk =[z0]
    print("t", "".ljust(2),"|","y", "".ljust(22), "|","x".ljust(25))
    print("-----------------------------------------------------")
    print(x0,"".ljust(3),"|", y0,"".ljust(23),"|",z0,"".ljust(25))
    for i in range(stepnum):
        y_temp = y0 + h * f(x0, y0, z0)
        y0 = y0 + (h/2) * (f(x0, y0, z0) + f(x0+h, y_temp, z0))
        
        z_temp = z0 + h * g(x0, y0, z0)
        z0 = z0 + (h/2) * (g(x0, y0, z0) + g(x0+h, y0, z_temp))
        
        x0 = x0 + h
        print(str(np.round(x0,3)).ljust(5) , "|", str(y0).ljust(25),"|",str(z0).ljust(7))
        xk.append(x0)
        yk.append(y0)
        zk.append(z0)
    return np.asarray(xk), np.asarray(yk), np.asarray(zk)

s1, s2, s3 = HinhThang(3.0, -0.5, 1.0, 6.0, 30)

fig = plt.figure(figsize = (16, 8))
plt.subplot(1, 2, 1)
plt.plot(s1, s3, 'go--', c = 'r', label = 'x(t)')
plt.plot(s1, s2, 'go--', c = 'b', label = 'y(t)')
plt.xlabel("Value of t")
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(s3, s2, 'go--', c = 'g', label = 'RK2')
plt.xlabel("Value of x")
plt.ylabel("Value of y")
plt.legend()
plt.show()
# Out:
# t    | y                        | x
# -----------------------------------------------------
# 3.0     | -0.5                         | 1.0
# 3.1   | -0.31999999999999995      | 0.7912
# 3.2   | -0.19119199999999995      | 0.63157672
# 3.3   | -0.09993553519999995      | 0.508898712232
# 3.4   | -0.03614625476311996      | 0.4140437811015592
# 3.5   | 0.007624011393381966      | 0.34020206152868293
# 3.6   | 0.03686987488015467       | 0.2822839791927339
# 3.7   | 0.055638855529072884      | 0.23648035993565836
# 3.8   | 0.06690709392804901       | 0.19993553360076427
# 3.9   | 0.07285801504506897       | 0.17050435890668292
# 4.0   | 0.07508896463855802       | 0.1465715811209502
# 4.1   | 0.0747643933045031        | 0.12691749191658444
# 4.2   | 0.07272937678218515       | 0.1106179872819959
# 4.3   | 0.06959370781677145       | 0.09697018327474606
# 4.4   | 0.06579415690447973       | 0.08543702440669494
# 4.5   | 0.06164054085827593       | 0.07560600869073468
# 4.6   | 0.05734978428595239       | 0.06715840771213816
# 4.7   | 0.05307107980857339       | 0.059846291506724894
# 4.8   | 0.04890445167863542       | 0.0534753596865916
# 4.9   | 0.04491443274827429       | 0.0478920938903498
# 5.0   | 0.0411401233037164        | 0.04297412808742131
# 5.1   | 0.03760257263691537       | 0.03862301656900786
# 5.2   | 0.03431018105348131       | 0.034758789881399764
# 5.3   | 0.031262639553180656      | 0.031315845262534066
# 5.4   | 0.028453790507236204      | 0.028239834260929193
# 5.5   | 0.025873693299417314      | 0.025485296490909498
# 5.6   | 0.02351010518970405       | 0.023013852589619153
# 5.7   | 0.021349532988623045      | 0.02079281709246378
# 5.8   | 0.019377970588992637      | 0.018794127368829638
# 5.9   | 0.01758140734616863       | 0.01699351110359548
# 6.0   | 0.01594617002318187       | 0.01536983440703466
# C:\Users\admin\AppData\Local\Temp/ipykernel_16672/2160370324.py:37: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "go--" (-> color='g'). The keyword argument will take precedence.
#   plt.plot(s1, s3, 'go--', c = 'r', label = 'x(t)')
# C:\Users\admin\AppData\Local\Temp/ipykernel_16672/2160370324.py:38: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "go--" (-> color='g'). The keyword argument will take precedence.
#   plt.plot(s1, s2, 'go--', c = 'b', label = 'y(t)')
# C:\Users\admin\AppData\Local\Temp/ipykernel_16672/2160370324.py:43: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "go--" (-> color='g'). The keyword argument will take precedence.
#   plt.plot(s3, s2, 'go--', c = 'g', label = 'RK2')
